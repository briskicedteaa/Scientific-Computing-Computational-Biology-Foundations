# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Scientific-Computing-Computational-Biology-Foundations/blob/main/Retrieving_Biological_Data_with_UniProt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install biopython
from Bio import SeqIO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 34.4 MB/s eta 0:00:00
# ...

# %%
SeqIO.parse("P14416.fasta", "fasta")

# %%
for record in SeqIO.parse("P14416.txt", "swiss"):
    print(f"Protein Name: {record.description}")
    print(f"Gene Name: {record.annotations['gene_name']}")
    print(f"Organism: {record.annotations['organism']}")
# Out:
# Protein Name: RecName: Full=D(2) dopamine receptor; AltName: Full=Dopamine D2 receptor;
# Gene Name: [{'Name': 'DRD2'}]
# Organism: Homo sapiens (Human)
