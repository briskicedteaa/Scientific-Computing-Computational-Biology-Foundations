# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Scientific-Computing-Computational-Biology-Foundations/blob/main/Pairwise_Sequence_Alignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install BioPython
from Bio import SeqIO
from Bio import Align
aligner = Align.PairwiseAligner()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 36.2 MB/s eta 0:00:00
# ...

# %%
for record in SeqIO.parse("P14416.fasta", "fasta"):
  print(f"Sequence: {record.seq}")
# Out:
# Sequence: ...

# %%
for record in SeqIO.parse("Q16620.fasta", "fasta"):
  print(f"Sequence: {record.seq}")
# Out:
# Sequence: ...
